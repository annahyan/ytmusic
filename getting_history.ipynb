# %%
from ytmusicapi import YTMusic

ytmusic = YTMusic('headers_auth.json')

# %%
liked_songs = ytmusic.get_liked_songs()

# %%
liked_songs
# Out:
# {'id': 'LM',
#  'privacy': 'PUBLIC',
#  'title': 'Your Likes',
#  'thumbnails': [{'url': 'https://www.gstatic.com/youtube/media/ytm/images/pbg/liked-songs-@192.png',
#    'width': 192,
#    'height': 192},
#   {'url': 'https://www.gstatic.com/youtube/media/ytm/images/pbg/liked-songs-@576.png',
#    'width': 576,
#    'height': 576},
#   {'url': 'https://www.gstatic.com/youtube/media/ytm/images/pbg/liked-songs-@1200.png',
#    'width': 1200,
#    'height': 1200}],
#  'description': 'Music you like in any YouTube app will show here. You can change this in Settings.',
#  'trackCount': 431,
#  'suggestions_token': None,
#  'tracks': [{'videoId': 'j3XQxFy2g6w',
#    'title': 'Mind Doodles',
#    'artists': [{'name': 'Gabriel Vitel', 'id': 'UCfehaS0Q9Xdm7GKJI4LBbjg'},
#     {'name': 'Alec Troniq', 'id': 'UCqMXdHlGHdGROZ9lu_caP3g'}],
#    'album': {'name': 'Mind Doodles', 'id': 'MPREb_oKE1bDSM13R'},
#    'likeStatus': 'LIKE',
# ...

# %%
my_history = ytmusic.get_history()

# %%
my_history[1]
# Out:
# {'videoId': 'uO_ld4OJe30',
#  'title': 'Superrich',
#  'artists': [{'name': 'Ten Fé', 'id': 'UCz5hJDsb2q1DP_AeV0siwwQ'}],
#  'album': {'name': 'Future Perfect, Present Tense', 'id': 'MPREb_zLIvvL19kvZ'},
#  'likeStatus': 'LIKE',
#  'thumbnails': [{'url': 'https://lh3.googleusercontent.com/cCdUHdYDLWM2EeB_CJJ2D-HA3wxbZmpnFfrVZehZD048UpLFxSVY73UuaDB1hBXXwwFQX0dlhYgF18Y=w60-h60-l90-rj',
#    'width': 60,
#    'height': 60},
#   {'url': 'https://lh3.googleusercontent.com/cCdUHdYDLWM2EeB_CJJ2D-HA3wxbZmpnFfrVZehZD048UpLFxSVY73UuaDB1hBXXwwFQX0dlhYgF18Y=w120-h120-l90-rj',
#    'width': 120,
#    'height': 120}],
#  'isAvailable': True,
#  'isExplicit': False,
#  'duration': '5:47',
#  'feedbackTokens': {'add': 'AB9zfpJpIsvd9vdXHLw0tTc_uk5E3emrGQ1K8dqT36bKBk11af7HLhlTH_f451FcPtFOyILvwiTEYHrW-cok67XmGIhZoKYPNg',
#   'remove': 'AB9zfpLuveyKero4Pp3EgnPlf3ZdS4b0WAu3wVEtHHbFL1DGut4Ohs2UvJp9seGtt-B7gzxXBOvK4ERJm2D65ER1PNsLZdQk1g'},
# ...

# %%
"{} - {}".format(my_history[1]['title'], my_history[1]['artists'][0]['name'])
# Out:
# 'Superrich - Ten Fé'

# %%
for elem in my_history:
    ss = "{} - {}".format(elem['title'], elem['artists'][0]['name'])
    print(ss)
# Out:
# Younger (Kygo Remix) - Seinabo Sey
# Superrich - Ten Fé
# Need To Feel Loved (Adam K & Soha Vocal Mix) (feat. Delline Bass) - Reflekt
# More (feat. Elena Pitoulis) - Jan Blomqvist
# Home - Klangkarussell
# Be Mine (Original Mix) - Stavros Sounds
# Step - Vampire Weekend
# Таллинн (Live) - Zero People
# Dungeon Sound - Gramatik
# Infinite Reflection - Kaleidoscope Jukebox
# Souverian - Andrew Bird
# Love and War - Fleurie
# Tykwer - HVOB
# Elara (Original Mix) - Parra for Cuva
# Bones (Be Svendsen's Rodeo Rerub) - Be Svendsen
# Ramuma - Alina Orlova
# Nottamun Town - Listenbee
# O Nem - Irina Dubtsova
# Behind Me - Teho
# Mind Doodles - Gabriel Vitel
# Pumpin Blood (Franne Remix) - NONONO
# Exploration - Karminsky Experience Inc.
# Благо Дарю - ОЛЬГА ГОРБАЧЕВА
# Vetrom Stat` - MakSim
# Ghost (Radio Edit) (feat. Clap Your Hands Say Yeah) - Claptone
# Lonely Land (feat. Sway Clarke II) - Alle Farben
# Never Never Ever - Alexandra Panayotova
# Follow You (feat. Muringa) - twocolors
# ...

# %%
for elem in my_history:
    if (elem['title'].startswith("D") ):
        ss = "{} - {}".format(elem['title'], elem['artists'][0]['name'])
        print(ss)
# Out:
# Dungeon Sound - Gramatik
# Dancing All the Time (Embody Remix) - Make Love
# Darling (feat. Missio) - Said The Sky
# Day And Night (Extended Mix) (feat. Mark Jarai) - Monkeyneck
# Dark, Dark, Dark - Gregory Alan Isakov
# Doing the Right Thing - Daughter
# Demi Moore - Phoebe Bridgers
# Dissatisfaction - Epic Mountain
